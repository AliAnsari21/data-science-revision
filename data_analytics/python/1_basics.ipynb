# %% [markdown]
# Print Statement

# %%
#to print any statement
print("hello world")
# Out:
# hello world
# hello world
# my name is Ali
# I hope you are doing good

# %%
#to give line break
print("""hello world
my name is Ali
I hope you are doing good""")
# Out:
# hello world
# my name is Ali
# I hope you are doing good

# %%
print("hello world \n my name is Ali\n I hope you are doing good")
# Out:
# hello world
#  my name is Ali
#  I hope you are doing good

# %% [markdown]
# Variables

# %%
a="hello world"
print(a)
# Out:
# hello world

# %% [markdown]
# Data Types and User_Input

# %%
#data types
"""
Text_type:-string(str)
Numeric_type:-integer(int),floating(float),complex
Sequence_type:-list,tuple,range
Mapping_type:-Dictionaries(dict)
Set_type:-set,frozenset
Boolean_type:-bool
Binary type:-bytes,byte,array,memoryview
"""

#user_input
name=input("enter your name")
print(name)
age=int(input("enter your age"))
print(age)
height=float(input("enter your height"))
print(height)
exp1=eval(input("enter your equation"))
print(exp1)
# Out:
# ali
# 10
# 2.0
# 4

# %% [markdown]
# Problem Solving

# %%
#write a program to display
